# %% [markdown]
# ##  visualize - ALE  results

# %%
from os import makedirs, path
from atlasreader import get_statmap_info
from IPython.display import display
from nilearn import image, plotting, reporting
from scipy import stats
from scipy.stats import pearsonr
from glob import glob
from pathlib import Path

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
import seaborn as sns
import os, fnmatch

import re
# Out:
# The Python package you are importing, AtlasReader, is licensed under the
# BSD-3 license; however, the atlases it uses are separately licensed under more
# restrictive frameworks.
# By using AtlasReader, you agree to abide by the license terms of the
# individual atlases. Information on these terms can be found online at:
# https://github.com/miykael/atlasreader/tree/master/atlasreader/data

# %%
# FIGURE：针对所有健康人的ALE结果进行可视化
import matplotlib.pyplot as plt 

ale_thresh_all = '/Users/ss/Documents/Psych_ALE_meta/results/ale/Self_all_z_size_level_thresh.nii.gz'

self_all = plotting.plot_glass_brain(ale_thresh_all, 
                                             display_mode="lyrz", 
                                             cmap="cold_white_hot", 
                                             vmin=0, vmax=5,
                                             colorbar=True)

# stat_map_all_cor = plotting.plot_stat_map(ale_thresh_all, 
#                                     colorbar=False, 
#                                     display_mode = 'ortho',
#                                     cut_coords=[-6,10,-2],
#                                     draw_cross = False,
#                                     cmap = "cold_white_hot", vmax=5)

# 保存可视化结果为不同格式  
plt.savefig('../results/figure/self_all.svg')  
plt.savefig('../results/figure/self_all.pdf')  
plt.savefig('../results/figure/self_all.png')

# %%
# FIGURE：针对所有健康人的ALE结果进行可视化
import matplotlib.pyplot as plt 

ale_thresh_st = '/Users/ss/Documents/Psych_ALE_meta/results/ale/Self_st_z_size_level_thresh.nii.gz'

self_st = plotting.plot_glass_brain(ale_thresh_st, 
                                             display_mode="lyrz", 
                                             cmap="cold_white_hot", 
                                             vmin=0, vmax=5,
                                             colorbar=True)

# stat_map_all_cor = plotting.plot_stat_map(ale_thresh_all, 
#                                     colorbar=False, 
#                                     display_mode = 'ortho',
#                                     cut_coords=[-6,10,-2],
#                                     draw_cross = False,
#                                     cmap = "cold_white_hot", vmax=5)

# 保存可视化结果为不同格式  
plt.savefig('../results/figure/self_st.svg')  
plt.savefig('../results/figure/self_st.pdf')  
plt.savefig('../results/figure/self_st.png')

# %%
# FIGURE：针对所有健康人的ALE结果进行可视化
import matplotlib.pyplot as plt 

ale_thresh_unhealth = '/Users/ss/Documents/Psych_ALE_meta/results/ale/unhealth_z_size_level_thresh.nii.gz'

self_unhealth = plotting.plot_glass_brain(ale_thresh_unhealth, 
                                             display_mode="lyrz", 
                                             cmap="cold_white_hot", 
                                             vmin=0, vmax=5,
                                             colorbar=True)

# stat_map_all_cor = plotting.plot_stat_map(ale_thresh_all, 
#                                     colorbar=False, 
#                                     display_mode = 'ortho',
#                                     cut_coords=[-6,10,-2],
#                                     draw_cross = False,
#                                     cmap = "cold_white_hot", vmax=5)

# 保存可视化结果为不同格式  
plt.savefig('../results/figure/self_unhealth.svg')  
plt.savefig('../results/figure/self_unhealth.pdf')  
plt.savefig('../results/figure/self_unhealth.png')
